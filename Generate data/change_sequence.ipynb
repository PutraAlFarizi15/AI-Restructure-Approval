# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/Dataset AI Restructure Approval rev7 04102023.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3777 entries, 0 to 3776
# Data columns (total 42 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   debtor_nik                      3777 non-null   int64
#  1   debtor_name                     3777 non-null   object
#  2   debtor_gender                   3777 non-null   object
#  3   debtor_birth_place              3777 non-null   object
#  4   debtor_address                  3777 non-null   object
#  5   debtor_zip                      3777 non-null   int64
#  6   debtor_rt                       3777 non-null   int64
#  7   debtor_rw                       3777 non-null   int64
#  8   debtor_marital_status           3777 non-null   object
#  9   debtor_company                  3777 non-null   object
#  10  debtor_number                   3777 non-null   object
#  11  debtor_id                       3777 non-null   int64
# ...

# %%
def calculate_monthly_payment(tenor, interest_rate, loan_amount):
  if(tenor == 0):
    return 0
  return ((loan_amount+(loan_amount*interest_rate/100))/tenor)
calculate_monthly_payment(33, 11, 7.624500e+07)
# Out:
# 2564604.5454545454

# %%
df['old_monthly_payments'] = np.where(df['old_tenor'] == 0, 0, (df['loan_amount'] + df['loan_amount'] * df['interest_rate'] / 100) / df['old_tenor'])
df.head(5)
# Out:
#          debtor_nik                   debtor_name debtor_gender  \
# 0  4133431716345918              Cemplunk Zulaika     perempuan
# 1  7873621118387801         Clara Padmasari, M.Pd     laki-laki
# 2  9937369990430445  Puti Cinthia Oktaviani, S.IP     laki-laki
# 3  2071079715934185          Lalita Astuti, M.TI.     laki-laki
# 4  8852740896362143                Daliman Kusumo     laki-laki
#
#         debtor_birth_place                                     debtor_address  \
# 0     Bengkulu, 23-09-1997  Jalan Raya Setiabudhi No. 857\nBanjarbaru, KR ...
# 1  Jawa Tengah, 13-04-1964  Jalan Cihampelas No. 4\nPekanbaru, Sulawesi Se...
# 2  Jawa Tengah, 01-09-1981           Jl. Wonoayu No. 68\nSemarang, Riau 98101
# 3         Aceh, 14-02-1987    Gg. Sentot Alibasa No. 781\nPontianak, SU 76993
# 4    Gorontalo, 06-12-1998   Jl. Ronggowarsito No. 0\nTanjungpinang, NB 06297
#
#    debtor_zip  debtor_rt  debtor_rw debtor_marital_status  \
# ...

# %%
output = ['old_monthly_payments', 'tenor', 'monthly_payments', 'loan_amount']
df_output = df[output]
df_output
# Out:
#       old_monthly_payments  tenor  monthly_payments   loan_amount
# 0             2.566954e+06    164     516521.263952  7.624500e+07
# 1             2.648156e+05     75     190667.231638  1.405000e+07
# 2             8.396498e+06    129     390534.774230  4.562333e+07
# 3             6.982353e+05     51     698235.294118  3.561000e+07
# 4             2.742593e+05     45     274259.259259  1.234167e+07
# ...                    ...    ...               ...           ...
# 3772          0.000000e+00      0          0.000000  0.000000e+00
# 3773          0.000000e+00      0          0.000000  0.000000e+00
# 3774          0.000000e+00      0          0.000000  0.000000e+00
# 3775          0.000000e+00      0          0.000000  0.000000e+00
# 3776          0.000000e+00      0          0.000000  0.000000e+00
#
# [3777 rows x 4 columns]

# %%
df = df.drop(output, axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3777 entries, 0 to 3776
# Data columns (total 39 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   debtor_nik                      3777 non-null   int64
#  1   debtor_name                     3777 non-null   object
#  2   debtor_gender                   3777 non-null   object
#  3   debtor_birth_place              3777 non-null   object
#  4   debtor_address                  3777 non-null   object
#  5   debtor_zip                      3777 non-null   int64
#  6   debtor_rt                       3777 non-null   int64
#  7   debtor_rw                       3777 non-null   int64
#  8   debtor_marital_status           3777 non-null   object
#  9   debtor_company                  3777 non-null   object
#  10  debtor_number                   3777 non-null   object
#  11  debtor_id                       3777 non-null   int64
# ...

# %%
# Menggabungkan kolom dari kedua DataFrame
df_gabung = pd.concat([df, df_output], axis=1)
df_gabung.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3777 entries, 0 to 3776
# Data columns (total 43 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   debtor_nik                      3777 non-null   int64
#  1   debtor_name                     3777 non-null   object
#  2   debtor_gender                   3777 non-null   object
#  3   debtor_birth_place              3777 non-null   object
#  4   debtor_address                  3777 non-null   object
#  5   debtor_zip                      3777 non-null   int64
#  6   debtor_rt                       3777 non-null   int64
#  7   debtor_rw                       3777 non-null   int64
#  8   debtor_marital_status           3777 non-null   object
#  9   debtor_company                  3777 non-null   object
#  10  debtor_number                   3777 non-null   object
#  11  debtor_id                       3777 non-null   int64
# ...

# %%
df_gabung[output]
# Out:
#       old_monthly_payments  tenor  monthly_payments   loan_amount
# 0             2.566954e+06    164     516521.263952  7.624500e+07
# 1             2.648156e+05     75     190667.231638  1.405000e+07
# 2             8.396498e+06    129     390534.774230  4.562333e+07
# 3             6.982353e+05     51     698235.294118  3.561000e+07
# 4             2.742593e+05     45     274259.259259  1.234167e+07
# ...                    ...    ...               ...           ...
# 3772          0.000000e+00      0          0.000000  0.000000e+00
# 3773          0.000000e+00      0          0.000000  0.000000e+00
# 3774          0.000000e+00      0          0.000000  0.000000e+00
# 3775          0.000000e+00      0          0.000000  0.000000e+00
# 3776          0.000000e+00      0          0.000000  0.000000e+00
#
# [3777 rows x 4 columns]

# %%
# Save DataFrame to file CSV
df_gabung.to_csv('../data/Dummy Data AI Restructure Approval rev7 05102023.csv', index=False)
