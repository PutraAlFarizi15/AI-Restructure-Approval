# %% [markdown]
# # Import Library

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/Dataset AI Restructure Approval rev7 05102023.csv')
df.tail(10)
# Out:
#             debtor_nik                debtor_name debtor_gender  \
# 3767  5332777817429456      Almira Ramadan, S.Kom     laki-laki
# 3768  5313124918708494          Latika Kuswandari     perempuan
# 3769  9710618535284629               Alika Marbun     perempuan
# 3770  3822949593142390             Dina Mandasari     laki-laki
# 3771  2080922958764444  R.A. Nurul Susanti, M.TI.     perempuan
# 3772  6151159536311156            Panji Anggraini     perempuan
# 3773  3342206439292911              Ganep Dabukke     perempuan
# 3774  5958944163024852           Puti Winda Uwais     laki-laki
# 3775  4816340735472205  T. Prayitna Habibi, S.Sos     perempuan
# 3776  5763714261175626             Latika Nababan     perempuan
#
#                 debtor_birth_place  \
# 3767  Kalimantan Barat, 21-11-1997
# 3768              Bali, 08-01-1978
# 3769    Kepulauan Riau, 27-11-1972
# 3770        Jawa Barat, 07-10-1961
# 3771    Kepulauan Riau, 10-08-1971
# 3772             Papua, 27-10-1971
# 3773             Papua, 20-04-1999
# 3774  Sumatera Selatan, 09-07-1986
# 3775       Papua Barat, 23-11-1999
# 3776       DKI Jakarta, 02-09-1962
#
#                                          debtor_address  debtor_zip  \
# 3767  Gg. Pelajar Pejuang No. 4\nYogyakarta, Goronta...       74624
# 3768  Gang Stasiun Wonokromo No. 4\nBekasi, Sumatera...       24942
# 3769             Gang Indragiri No. 7\nKediri, JB 31978       31978
# 3770  Jl. Pacuan Kuda No. 777\nSemarang, Maluku Utar...       35778
# 3771  Gg. Tebet Barat Dalam No. 415\nSurakarta, Jawa...       41126
# 3772   Jalan Lembong No. 6\nPayakumbuh, Gorontalo 67113       67113
# 3773  Gang Tubagus Ismail No. 46\nKota Administrasi ...       41755
# 3774      Jl. Yos Sudarso No. 85\nLhokseumawe, BE 98778       98778
# 3775           Jl. Monginsidi No. 622\nBinjai, BB 06240        6240
# 3776  Jl. Otto Iskandardinata No. 74\nSungai Penuh, ...       18130
#
#       debtor_rt  debtor_rw debtor_marital_status  \
# 3767         20         17               Menikah
# 3768          6          7            Cerai mati
# 3769          2         12            Cerai mati
# 3770          7         10           Cerai hidup
# 3771          3          6            Cerai mati
# 3772         12         11           Cerai hidup
# 3773          6          6            Cerai mati
# 3774         13         10         Belum menikah
# 3775         17          8           Cerai hidup
# 3776          1         18               Menikah
#
#                          debtor_company  ... remaining_loan  arrear_amount  \
# 3767                 Perum Astuti Usada  ...              0              2
# 3768               UD Wastuti Mardhiyah  ...              0              3
# 3769                PT Saragih Setiawan  ...              0              1
# 3770                   CV Kusmawati Tbk  ...              0              1
# 3771            PD Sihotang Uyainah Tbk  ...              0              4
# 3772  PD Yulianti Nugroho (Persero) Tbk  ...              0              1
# 3773                     PT Susanti Tbk  ...              0              3
# 3774            PD Kusumo (Persero) Tbk  ...              0              3
# 3775                      Perum Halimah  ...              0              5
# 3776                 Perum Yuliarti Tbk  ...              0              2
#
#       monthly_income_family monthly_expense_family  family_health  \
# 3767                2500000                3800000          Sehat
# 3768               19400000                3900000    Tidak sehat
# 3769               23500000                3900000          Sehat
# 3770               14400000                6000000          Sehat
# 3771               29300000                1300000    Tidak sehat
# 3772               26400000                3300000    Tidak sehat
# 3773               12300000                4800000    Tidak sehat
# 3774                6400000                2200000    Tidak sehat
# 3775                6200000                5000000    Tidak sehat
# 3776               11600000                7800000          Sehat
#
#       asset_value_family  old_monthly_payments  tenor  monthly_payments  \
# 3767            81700000                   0.0      0               0.0
# 3768            33700000                   0.0      0               0.0
# 3769            18200000                   0.0      0               0.0
# 3770            75700000                   0.0      0               0.0
# 3771            33400000                   0.0      0               0.0
# 3772            40200000                   0.0      0               0.0
# 3773            86200000                   0.0      0               0.0
# 3774            37600000                   0.0      0               0.0
# 3775            40500000                   0.0      0               0.0
# 3776            49000000                   0.0      0               0.0
#
#       loan_amount
# 3767          0.0
# 3768          0.0
# 3769          0.0
# 3770          0.0
# 3771          0.0
# 3772          0.0
# 3773          0.0
# 3774          0.0
# 3775          0.0
# 3776          0.0
#
# [10 rows x 43 columns]

# %% [markdown]
# # EDA (Exploratory Data Analysis)

# %% [markdown]
# ### Informasi data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3777 entries, 0 to 3776
# Data columns (total 43 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   debtor_nik                      3777 non-null   int64
#  1   debtor_name                     3777 non-null   object
#  2   debtor_gender                   3777 non-null   object
#  3   debtor_birth_place              3777 non-null   object
#  4   debtor_address                  3777 non-null   object
#  5   debtor_zip                      3777 non-null   int64
#  6   debtor_rt                       3777 non-null   int64
#  7   debtor_rw                       3777 non-null   int64
#  8   debtor_marital_status           3777 non-null   object
#  9   debtor_company                  3777 non-null   object
#  10  debtor_number                   3777 non-null   object
#  11  debtor_id                       3777 non-null   int64
#  12  debtor_age                      3777 non-null   int64
#  13  debtor_occupation               3777 non-null   object
#  14  monthly_income                  3777 non-null   int64
#  15  debt                            3777 non-null   float64
#  16  dti                             3777 non-null   float64
#  17  monthly_expenses                3777 non-null   int64
#  18  net_income                      3777 non-null   int64
#  19  asset_value                     3777 non-null   int64
#  20  previous_credit_monthly_income  3777 non-null   int64
#  21  financial_changes               3777 non-null   int64
#  22  business_conditions             3777 non-null   int64
#  23  credit_score                    3777 non-null   int64
#  24  amount_of_late_days             3777 non-null   int64
#  25  credit_goals                    3777 non-null   object
#  26  collateral                      3777 non-null   int64
#  27  interest_rate                   3777 non-null   float64
#  28  number_of_dependents            3777 non-null   int64
#  29  old_tenor                       3777 non-null   int64
#  30  old_collateral                  3777 non-null   int64
#  31  fee_installments                3777 non-null   int64
#  32  ltv                             3777 non-null   float64
#  33  remaining_loan                  3777 non-null   int64
#  34  arrear_amount                   3777 non-null   int64
#  35  monthly_income_family           3777 non-null   int64
#  36  monthly_expense_family          3777 non-null   int64
#  37  family_health                   3777 non-null   object
#  38  asset_value_family              3777 non-null   int64
#  39  old_monthly_payments            3777 non-null   float64
#  40  tenor                           3777 non-null   int64
#  41  monthly_payments                3777 non-null   float64
#  42  loan_amount                     3777 non-null   float64
# dtypes: float64(7), int64(26), object(10)
# memory usage: 1.2+ MB

# %% [markdown]
# ### Deskripsi statistik

# %%
df.describe()
# Out:
#          debtor_nik    debtor_zip    debtor_rt    debtor_rw     debtor_id  \
# count  3.777000e+03   3777.000000  3777.000000  3777.000000  3.777000e+03
# mean   5.494099e+15  50492.760392    10.706116    10.674080  3.797036e+17
# std    2.593223e+15  28864.368097     5.785351     5.798474  1.251357e+18
# min    1.001567e+15     64.000000     1.000000     1.000000  6.040096e+10
# 25%    3.248973e+15  24764.000000     6.000000     6.000000  1.800058e+14
# 50%    5.502578e+15  51857.000000    11.000000    11.000000  3.518681e+15
# 75%    7.779147e+15  75019.000000    16.000000    16.000000  4.671615e+15
# max    9.996336e+15  99979.000000    20.000000    20.000000  4.999998e+18
#
#         debtor_age  monthly_income          debt          dti  \
# count  3777.000000    3.777000e+03  3.777000e+03  3777.000000
# mean     41.281176    3.855976e+07  3.870212e+06     0.161762
# std      13.770376    2.586694e+07  2.356101e+06     0.253931
# min      18.000000    1.000000e+06  8.333333e+04     0.000966
# 25%      29.000000    1.920000e+07  1.833333e+06     0.056727
# 50%      41.000000    3.310000e+07  3.625000e+06     0.112245
# 75%      53.000000    5.220000e+07  5.858333e+06     0.201346
# max      65.000000    1.000000e+08  8.333333e+06     5.628788
#
#        monthly_expenses  ...          ltv  remaining_loan  arrear_amount  \
# count      3.777000e+03  ...  3777.000000    3.777000e+03    3777.000000
# mean       1.952438e+07  ...     1.036727    1.627961e+07       2.638602
# std        1.800117e+07  ...     0.587153    1.494687e+07       1.457710
# min        1.000000e+06  ...     0.000000    0.000000e+00       0.000000
# 25%        6.000000e+06  ...     0.843468    4.700000e+06       2.000000
# 50%        1.390000e+07  ...     0.899901    1.170000e+07       2.000000
# 75%        2.770000e+07  ...     1.014638    2.400000e+07       3.000000
# max        9.740000e+07  ...     8.775000    8.020000e+07      10.000000
#
#        monthly_income_family  monthly_expense_family  asset_value_family  \
# count           3.777000e+03            3.777000e+03        3.777000e+03
# mean            3.541530e+07            1.975107e+07        5.087752e+07
# std             2.701843e+07            1.811737e+07        2.871560e+07
# min             1.000000e+06            1.000000e+06        1.000000e+06
# 25%             1.300000e+07            6.000000e+06        2.610000e+07
# 50%             2.960000e+07            1.410000e+07        5.120000e+07
# 75%             4.980000e+07            2.750000e+07        7.600000e+07
# max             1.000000e+08            9.620000e+07        1.000000e+08
#
#        old_monthly_payments        tenor  monthly_payments   loan_amount
# count          3.777000e+03  3777.000000      3.777000e+03  3.777000e+03
# mean           2.076167e+06    78.043685      7.734235e+05  3.312034e+07
# std            3.205965e+06    45.866856      1.833816e+06  2.024550e+07
# min            0.000000e+00     0.000000      0.000000e+00  0.000000e+00
# 25%            5.192010e+05    43.000000      2.699223e+05  1.599167e+07
# 50%            1.071356e+06    74.000000      4.115456e+05  3.113333e+07
# 75%            2.173924e+06   112.000000      5.572486e+05  4.793833e+07
# max            3.177331e+07   180.000000      2.504444e+07  8.487000e+07
#
# [8 rows x 33 columns]

# %% [markdown]
# ### Checking valui tenor is 0

# %%
df.loc[df['tenor'] == 0].count()
# Out:
# debtor_nik                        100
# debtor_name                       100
# debtor_gender                     100
# debtor_birth_place                100
# debtor_address                    100
# debtor_zip                        100
# debtor_rt                         100
# debtor_rw                         100
# debtor_marital_status             100
# debtor_company                    100
# debtor_number                     100
# debtor_id                         100
# debtor_age                        100
# debtor_occupation                 100
# monthly_income                    100
# debt                              100
# dti                               100
# monthly_expenses                  100
# net_income                        100
# asset_value                       100
# previous_credit_monthly_income    100
# financial_changes                 100
# business_conditions               100
# credit_score                      100
# amount_of_late_days               100
# credit_goals                      100
# collateral                        100
# interest_rate                     100
# number_of_dependents              100
# old_tenor                         100
# old_collateral                    100
# fee_installments                  100
# ltv                               100
# remaining_loan                    100
# arrear_amount                     100
# monthly_income_family             100
# monthly_expense_family            100
# family_health                     100
# asset_value_family                100
# old_monthly_payments              100
# tenor                             100
# monthly_payments                  100
# loan_amount                       100
# dtype: int64

# %% [markdown]
# ### Checking missing value

# %%
df.isna().sum()
# Out:
# debtor_nik                        0
# debtor_name                       0
# debtor_gender                     0
# debtor_birth_place                0
# debtor_address                    0
# debtor_zip                        0
# debtor_rt                         0
# debtor_rw                         0
# debtor_marital_status             0
# debtor_company                    0
# debtor_number                     0
# debtor_id                         0
# debtor_age                        0
# debtor_occupation                 0
# monthly_income                    0
# debt                              0
# dti                               0
# monthly_expenses                  0
# net_income                        0
# asset_value                       0
# previous_credit_monthly_income    0
# financial_changes                 0
# business_conditions               0
# credit_score                      0
# amount_of_late_days               0
# credit_goals                      0
# collateral                        0
# interest_rate                     0
# number_of_dependents              0
# old_tenor                         0
# old_collateral                    0
# fee_installments                  0
# ltv                               0
# remaining_loan                    0
# arrear_amount                     0
# monthly_income_family             0
# monthly_expense_family            0
# family_health                     0
# asset_value_family                0
# old_monthly_payments              0
# tenor                             0
# monthly_payments                  0
# loan_amount                       0
# dtype: int64

# %% [markdown]
# ### Checking duplicate data

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Histogram plot

# %%
#sns.pairplot(df)

# %%
for column in df.columns:
    plt.figure(figsize=(16, 7))
    sns.histplot(df[column], kde=True)# label = 'Skewness: %.2f'%(df[column].skew()))
    plt.title(f'Distribution of {column}')
    plt.legend(loc = 'best')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df.isnull().sum() #checking for total null values
# Out:
# debtor_nik                        0
# debtor_name                       0
# debtor_gender                     0
# debtor_birth_place                0
# debtor_address                    0
# debtor_zip                        0
# debtor_rt                         0
# debtor_rw                         0
# debtor_marital_status             0
# debtor_company                    0
# debtor_number                     0
# debtor_id                         0
# debtor_age                        0
# debtor_occupation                 0
# monthly_income                    0
# debt                              0
# dti                               0
# monthly_expenses                  0
# net_income                        0
# asset_value                       0
# previous_credit_monthly_income    0
# financial_changes                 0
# business_conditions               0
# credit_score                      0
# amount_of_late_days               0
# credit_goals                      0
# collateral                        0
# interest_rate                     0
# number_of_dependents              0
# old_tenor                         0
# old_collateral                    0
# fee_installments                  0
# ltv                               0
# remaining_loan                    0
# arrear_amount                     0
# monthly_income_family             0
# monthly_expense_family            0
# family_health                     0
# asset_value_family                0
# old_monthly_payments              0
# tenor                             0
# monthly_payments                  0
# loan_amount                       0
# dtype: int64

# %% [markdown]
# No Missing Value tidak perlu melakukan Imputasi dan lainnya

# %% [markdown]
# ### Korelasi pekerjaan dan gaji

# %%
f, ax = plt.subplots(figsize=(18, 8))

# Bar plot for mean monthly income based on type of job
df[['debtor_occupation', 'monthly_income']].groupby(['debtor_occupation']).mean().plot.bar(ax=ax)
ax.set_title('occupation vs monthly_income')

plt.show()

# %% [markdown]
# ### HeatMap data

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(18, 15))
sns.heatmap(df.corr(),annot=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_19088\2670240793.py:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >
